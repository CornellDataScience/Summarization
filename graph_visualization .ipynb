# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
import graph_summarize as m

# %%
g = nx.connected_watts_strogatz_graph(20,4,0.3)

# %%
nx.draw_networkx(g)

# %%
g_sum = m.greedy_summarize(g, 2, 0.01)
nx.draw_networkx(g_sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d7af7eba0127> in <module>()
# ----> 1 g_sum = m.greedy_summarize(g, 2, 0.01, 1)
#       2 nx.draw_networkx(g_sum)
#
# /Users/Jane/Desktop/School/CDS/Summarization/graph_summarize.py in greedy_summarize(G, k, c, degree_weight)
#      31     selected = []
#      32     dom = []
# ---> 33     print("g1: "  + str(G.nodes[1]))
#      34     largest_degree_vs = sorted(G.nodes.keys(), key=lambda i: G.nodes[i]['weight'] + G.degree()[i] * degree_weight) [-k:]
#      35     for i in largest_degree_vs:
#
# TypeError: 'method' object is not subscriptable

# %%
g = nx.dorogovtsev_goltsev_mendes_graph(3)
nx.draw_networkx(g)

# %%
g_sum = m.greedy_summarize(g, 3, 0.001)
nx.draw_networkx(g_sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1a59d4d42126> in <module>()
# ----> 1 g_sum = m.greedy_summarize(g, 3, 0.001, 1)
#       2 nx.draw_networkx(g_sum)
#
# /Users/Jane/Desktop/School/CDS/Summarization/graph_summarize.py in greedy_summarize(G, k, c, degree_weight)
#      31     selected = []
#      32     dom = []
# ---> 33     print("g1: "  + str(G.nodes[1]))
#      34     largest_degree_vs = sorted(G.nodes.keys(), key=lambda i: G.nodes[i]['weight'] + G.degree()[i] * degree_weight) [-k:]
#      35     for i in largest_degree_vs:
#
# TypeError: 'method' object is not subscriptable

# %%
from networkx import algorithms as algo

# %%
gen = algo.traversal.dfs_edges(g)
for g in gen:
    print(g)
# Out:
# (0, 1)
# (1, 2)
# (2, 4)
# (4, 9)
# (4, 13)
# (2, 5)
# (5, 12)
# (5, 14)
# (2, 7)
# (2, 10)
# (1, 3)
# (3, 8)
# (3, 11)
# (1, 6)
